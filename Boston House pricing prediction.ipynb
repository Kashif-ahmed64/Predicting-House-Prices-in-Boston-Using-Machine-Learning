# %%
# %matplotlib inline
from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np
from scipy.stats import trim_mean
from statsmodels import robust

# %%
pip install wquantiles

# %%
import wquantiles

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#task_1

import pandas as pd
vars = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
HOUSE_CSV = '/content/drive/My Drive/datascience/housing.csv'
pdata = pd.read_csv(HOUSE_CSV, delim_whitespace=True, names=vars)

# %%
#task_2
print(pdata.head(10))
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# ...

# %%
#task_3

m_calc= pdata.mean()
print("Mean values of input columns:")
print(m_calc)
# Out:
# Mean values of input columns:
# CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# MEDV        22.532806
# dtype: float64

# %%
#task_4
plt.figure(figsize=(12, 8))
sns.boxplot(data=pdata[input_columns])
plt.xticks(rotation=45)
plt.title('Boxplot of Deviation for Input Columns')
plt.xlabel('Input Variables')
plt.ylabel('Value')
plt.show()

# %%
#task_5

corr_matrix = pdata.corr()
corr_with_opt = abs(corr_matrix['MEDV']).sort_values(ascending=False)
fmiv = corr_with_opt[1:6]
print("Correlation with 'MEDV':")
print(corr_with_opt)
print("\nFive Most Important Variables:")
print(fmiv)
# Out:
# Correlation with 'MEDV':
# MEDV       1.000000
# LSTAT      0.737663
# RM         0.695360
# PTRATIO    0.507787
# INDUS      0.483725
# TAX        0.468536
# NOX        0.427321
# CRIM       0.388305
# RAD        0.381626
# AGE        0.376955
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# Name: MEDV, dtype: float64
#
# Five Most Important Variables:
# LSTAT      0.737663
# RM         0.695360
# PTRATIO    0.507787
# INDUS      0.483725
# TAX        0.468536
# Name: MEDV, dtype: float64

# %%
#task_6
imp_vars = ['CRIM', 'RM', 'AGE', 'DIS', 'TAX', 'MEDV']
for var in variables_of_interest[:-1]:
    plt.figure(figsize=(8, 6))
    plt.scatter(pdata [var], pdata ['MEDV'], alpha=0.5)
    plt.title(f'Scatter plot of {var} vs. MEDV')
    plt.xlabel(var)
    plt.ylabel('MEDV')
    plt.grid(True)
    plt.show()
